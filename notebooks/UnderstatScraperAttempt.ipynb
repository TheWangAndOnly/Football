# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests 
from bs4 import BeautifulSoup
import json
from pprint import pprint
import matplotlib.image as mpimg
import matplotlib.patches as patches
from PIL import Image
from io import BytesIO
from highlight_text import htext
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
from mplsoccer.pitch import Pitch


pd.set_option("display.max_rows", None, "display.max_columns", None)
background = "#463F3A"
text_color = 'w'
primary = '#C8102E'
secondary = 'lightblue'
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

# %%
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match
# Out:
# Please enter the match id: 17706

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
scripts = soup.find_all('script')

# %%
print(scripts[1].string)
# Out:
# 	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22457001\x22,\x22minute\x22\x3A\x225\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.865\x22,\x22Y\x22\x3A\x220.25299999237060544\x22,\x22xG\x22\x3A\x220.051986921578645706\x22,\x22player\x22\x3A\x22J\x5Cu00fcrgen\x20Locadia\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x226542\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2217706\x22,\x22h_team\x22\x3A\x22Bochum\x22,\x22a_team\x22\x3A\x22Bayern\x20Munich\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Gerrit\x20Holtmann\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22457003\x22,\x22minute\x22\x3A\x2213\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.8540000152587891\x22,\x22Y\x22\x3A\x220.49400001525878906\x22,\x22xG\x22\x3A\x220.12363068759441376\x22,\x22player\x22\x3A\x22Christopher\x20Antwi\x2DAdjei\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227798\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2217706\x22,\x22h_team\x22\x3A\x22Bochum\x22,\x22a_team\x22\x3A\x22Bayern\x20Munich\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Gerrit\x20Holtmann\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22457008\x22,\x22minute\x22\x3A\x2229\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.914000015258789\x22,\x22Y\x22\x3A\x220.485\x22,\x22xG\x22\x3A\x220.056819748133420944\x22,\x22player\x22\x3A\x22Anthony\x20Losilla\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x229705\x22,\x22situation\x22\x3A\x22SetPiece\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22Head\x22,\x22match_id\x22\x3A\x2217706\x22,\x22h_team\x22\x3A\x22Bochum\x22,\x22a_team\x22\x3A\x22Bayern\x20Munich\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Elvis\x20Rexhbecaj\x22,\x22lastAction\x22\x3A\x22Aerial\x22\x7D,\x7B\x22id\x22\x3A\x22457010\x22,\x22minute\x22\x3A\x2232\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.8880000305175781\x22,\x22Y\x22\x3A\x220.7480000305175781\x22,\x22xG\x22\x3A\x220.034214455634355545\x22,\x22player\x22\x3A\x22Gerrit\x20Holtmann\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225270\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2217706\x22,\x22h_team\x22\x3A\x22Bochum\x22,\x22a_team\x22\x3A\x22Bayern\x20Munich\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22J\x5Cu00fcrgen\x20Locadia\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22457011\x22,\x22minute\x22\x3A\x2237\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.885\x22,\x22Y\x22\x3A\x220.5\x22,\x22xG\x22\x3A\x220.757696270942688\x22,\x22player\x22\x3A\x22J\x5Cu00fcrgen\x20Locadia\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x226542\x22,\x22situation\x22\x3A\x22Penalty\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2217706\x22,\x22h_team\x22\x3A\x22Bochum\x22,\x22a_team\x22\x3A\x22Bayern\x20Munich\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22Standard\x22\x7D,\x7B\x22id\x22\x3A\x22457012\x22,\x22minute\x22\x3A\x2238\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.899000015258789\x22,\x22Y\x22\x3A\x220.40900001525878904\x22,\x22xG\x22\x3A\x220.12290242314338684\x22,\x22player\x22\x3A\x22E ...
# 		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2217706\x22,\x22fid\x22\x3A\x221557512\x22,\x22h\x22\x3A\x22268\x22,\x22a\x22\x3A\x22117\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22league_id\x22\x3A\x223\x22,\x22season\x22\x3A\x222021\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Bochum\x22,\x22team_a\x22\x3A\x22Bayern\x20Munich\x22,\x22h_xg\x22\x3A\x221.34846\x22,\x22a_xg\x22\x3A\x221.87083\x22,\x22h_w\x22\x3A\x220.2366\x22,\x22h_d\x22\x3A\x220.27\x22,\x22h_l\x22\x3A\x220.4934\x22,\x22league\x22\x3A\x22Bundesliga\x22,\x22h_shot\x22\x3A\x2211\x22,\x22a_shot\x22\x3A\x2221\x22,\x22h_shotOnTarget\x22\x3A\x226\x22,\x22a_shotOnTarget\x22\x3A\x224\x22,\x22h_deep\x22\x3A\x226\x22,\x22a_deep\x22\x3A\x2210\x22,\x22a_ppda\x22\x3A\x228.0667\x22,\x22h_ppda\x22\x3A\x2212.8261\x22\x7D');

# %%
script_ = scripts[2].string

start_index_ = script_.index("('")+2
end_index_ = script_.index("')")
json_string_ = script_[start_index:end_index]
json_string_ = json_string_.encode("utf8").decode("unicode_escape")
players_dict_ = json.loads(json_string)

# %%
players_dict_
# Out:
# {'h': [{'id': '457001',
#    'minute': '5',
#    'result': 'MissedShots',
#    'X': '0.865',
#    'Y': '0.25299999237060544',
#    'xG': '0.051986921578645706',
#    'player': 'Jürgen Locadia',
#    'h_a': 'h',
#    'player_id': '6542',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Gerrit Holtmann',
#    'lastAction': 'Pass'},
#   {'id': '457003',
#    'minute': '13',
#    'result': 'Goal',
#    'X': '0.8540000152587891',
#    'Y': '0.49400001525878906',
#    'xG': '0.12363068759441376',
#    'player': 'Christopher Antwi-Adjei',
#    'h_a': 'h',
#    'player_id': '7798',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Gerrit Holtmann',
#    'lastAction': 'Pass'},
#   {'id': '457008',
#    'minute': '29',
#    'result': 'MissedShots',
#    'X': '0.914000015258789',
#    'Y': '0.485',
#    'xG': '0.056819748133420944',
#    'player': 'Anthony Losilla',
#    'h_a': 'h',
#    'player_id': '9705',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Elvis Rexhbecaj',
#    'lastAction': 'Aerial'},
#   {'id': '457010',
#    'minute': '32',
#    'result': 'SavedShot',
#    'X': '0.8880000305175781',
#    'Y': '0.7480000305175781',
#    'xG': '0.034214455634355545',
#    'player': 'Gerrit Holtmann',
#    'h_a': 'h',
#    'player_id': '5270',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Jürgen Locadia',
#    'lastAction': 'Pass'},
#   {'id': '457011',
#    'minute': '37',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.757696270942688',
#    'player': 'Jürgen Locadia',
#    'h_a': 'h',
#    'player_id': '6542',
#    'situation': 'Penalty',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '457012',
#    'minute': '38',
#    'result': 'BlockedShot',
#    'X': '0.899000015258789',
#    'Y': '0.40900001525878904',
#    'xG': '0.12290242314338684',
#    'player': 'Elvis Rexhbecaj',
#    'h_a': 'h',
#    'player_id': '6445',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Jürgen Locadia',
#    'lastAction': 'Pass'},
#   {'id': '457013',
#    'minute': '39',
#    'result': 'Goal',
#    'X': '0.8719999694824219',
#    'Y': '0.27100000381469724',
#    'xG': '0.04876398667693138',
#    'player': 'Cristian Gamboa',
#    'h_a': 'h',
#    'player_id': '855',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Patrick Osterhage',
#    'lastAction': 'Pass'},
#   {'id': '457014',
#    'minute': '43',
#    'result': 'Goal',
#    'X': '0.8219999694824218',
#    'Y': '0.7609999847412109',
#    'xG': '0.036935821175575256',
#    'player': 'Gerrit Holtmann',
#    'h_a': 'h',
#    'player_id': '5270',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'TakeOn'},
#   {'id': '457015',
#    'minute': '45',
#    'result': 'SavedShot',
#    'X': '0.94',
#    'Y': '0.6780000305175782',
#    'xG': '0.06997985392808914',
#    'player': 'Gerrit Holtmann',
#    'h_a': 'h',
#    'player_id': '5270',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '457016',
#    'minute': '46',
#    'result': 'MissedShots',
#    'X': '0.7919999694824219',
#    'Y': '0.669000015258789',
#    'xG': '0.019206803292036057',
#    'player': 'Gerrit Holtmann',
#    'h_a': 'h',
#    'player_id': '5270',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '457023',
#    'minute': '62',
#    'result': 'MissedShots',
#    'X': '0.7469999694824219',
#    'Y': '0.25799999237060545',
#    'xG': '0.02632487751543522',
#    'player': 'Gerrit Holtmann',
#    'h_a': 'h',
#    'player_id': '5270',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Christopher Antwi-Adjei',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '457002',
#    'minute': '8',
#    'result': 'Goal',
#    'X': '0.9569999694824218',
#    'Y': '0.524000015258789',
#    'xG': '0.5958917140960693',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Kingsley Coman',
#    'lastAction': 'HeadPass'},
#   {'id': '457004',
#    'minute': '16',
#    'result': 'BlockedShot',
#    'X': '0.8980000305175782',
#    'Y': '0.639000015258789',
#    'xG': '0.08803185075521469',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Thomas Müller',
#    'lastAction': 'Pass'},
#   {'id': '457005',
#    'minute': '19',
#    'result': 'MissedShots',
#    'X': '0.9169999694824219',
#    'Y': '0.519000015258789',
#    'xG': '0.044338859617710114',
#    'player': 'Dayotchanculle Upamecano',
#    'h_a': 'a',
#    'player_id': '5243',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Joshua Kimmich',
#    'lastAction': 'Aerial'},
#   {'id': '457006',
#    'minute': '25',
#    'result': 'MissedShots',
#    'X': '0.76',
#    'Y': '0.6680000305175782',
#    'xG': '0.020942745730280876',
#    'player': 'Kingsley Coman',
#    'h_a': 'a',
#    'player_id': '226',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Thomas Müller',
#    'lastAction': 'Pass'},
#   {'id': '457007',
#    'minute': '28',
#    'result': 'MissedShots',
#    'X': '0.7290000152587891',
#    'Y': '0.5920000076293945',
#    'xG': '0.01869025081396103',
#    'player': 'Joshua Kimmich',
#    'h_a': 'a',
#    'player_id': '223',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Niklas Süle',
#    'lastAction': 'Pass'},
#   {'id': '457009',
#    'minute': '31',
#    'result': 'BlockedShot',
#    'X': '0.9359999847412109',
#    'Y': '0.5840000152587891',
#    'xG': '0.11412101984024048',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Serge Gnabry',
#    'lastAction': 'Chipped'},
#   {'id': '457017',
#    'minute': '49',
#    'result': 'SavedShot',
#    'X': '0.84',
#    'Y': '0.48700000762939455',
#    'xG': '0.0811324343085289',
#    'player': 'Thomas Müller',
#    'h_a': 'a',
#    'player_id': '224',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Serge Gnabry',
#    'lastAction': 'Pass'},
#   {'id': '457018',
#    'minute': '51',
#    'result': 'BlockedShot',
#    'X': '0.9619999694824218',
#    'Y': '0.69',
#    'xG': '0.12276137620210648',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Kingsley Coman',
#    'lastAction': 'TakeOn'},
#   {'id': '457019',
#    'minute': '52',
#    'result': 'MissedShots',
#    'X': '0.9080000305175782',
#    'Y': '0.285',
#    'xG': '0.041767992079257965',
#    'player': 'Niklas Süle',
#    'h_a': 'a',
#    'player_id': '75',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Serge Gnabry',
#    'lastAction': 'Pass'},
#   {'id': '457020',
#    'minute': '54',
#    'result': 'BlockedShot',
#    'X': '0.8530000305175781',
#    'Y': '0.5220000076293946',
#    'xG': '0.05310985818505287',
#    'player': 'Thomas Müller',
#    'h_a': 'a',
#    'player_id': '224',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Kingsley Coman',
#    'lastAction': 'Chipped'},
#   {'id': '457021',
#    'minute': '58',
#    'result': 'MissedShots',
#    'X': '0.730999984741211',
#    'Y': '0.53',
#    'xG': '0.055436063557863235',
#    'player': 'Leroy Sané',
#    'h_a': 'a',
#    'player_id': '337',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '457022',
#    'minute': '62',
#    'result': 'SavedShot',
#    'X': '0.865',
#    'Y': '0.4909999847412109',
#    'xG': '0.3237653076648712',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Leroy Sané',
#    'lastAction': 'TakeOn'},
#   {'id': '457024',
#    'minute': '64',
#    'result': 'MissedShots',
#    'X': '0.7730000305175782',
#    'Y': '0.43',
#    'xG': '0.029399709776043892',
#    'player': 'Leroy Sané',
#    'h_a': 'a',
#    'player_id': '337',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Joshua Kimmich',
#    'lastAction': 'Pass'},
#   {'id': '457025',
#    'minute': '74',
#    'result': 'Goal',
#    'X': '0.9109999847412109',
#    'Y': '0.6580000305175782',
#    'xG': '0.0260273739695549',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '457026',
#    'minute': '76',
#    'result': 'MissedShots',
#    'X': '0.74',
#    'Y': '0.705999984741211',
#    'xG': '0.012059362605214119',
#    'player': 'Eric Maxim Choupo-Moting',
#    'h_a': 'a',
#    'player_id': '339',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Corentin Tolisso',
#    'lastAction': 'Pass'},
#   {'id': '457027',
#    'minute': '77',
#    'result': 'BlockedShot',
#    'X': '0.82',
#    'Y': '0.5540000152587891',
#    'xG': '0.04307115450501442',
#    'player': 'Leroy Sané',
#    'h_a': 'a',
#    'player_id': '337',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '457028',
#    'minute': '78',
#    'result': 'MissedShots',
#    'X': '0.9309999847412109',
#    'Y': '0.44',
#    'xG': '0.04323367401957512',
#    'player': 'Corentin Tolisso',
#    'h_a': 'a',
#    'player_id': '3603',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Joshua Kimmich',
#    'lastAction': 'Aerial'},
#   {'id': '457029',
#    'minute': '85',
#    'result': 'ShotOnPost',
#    'X': '0.735999984741211',
#    'Y': '0.605',
#    'xG': '0.05287111550569534',
#    'player': 'Robert Lewandowski',
#    'h_a': 'a',
#    'player_id': '227',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '457030',
#    'minute': '85',
#    'result': 'BlockedShot',
#    'X': '0.8859999847412109',
#    'Y': '0.5540000152587891',
#    'xG': '0.015120120719075203',
#    'player': 'Eric Maxim Choupo-Moting',
#    'h_a': 'a',
#    'player_id': '339',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '457031',
#    'minute': '87',
#    'result': 'BlockedShot',
#    'X': '0.8680000305175781',
#    'Y': '0.315',
#    'xG': '0.03925004228949547',
#    'player': 'Serge Gnabry',
#    'h_a': 'a',
#    'player_id': '993',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': 'Marcel Sabitzer',
#    'lastAction': 'HeadPass'},
#   {'id': '457032',
#    'minute': '87',
#    'result': 'MissedShots',
#    'X': '0.955',
#    'Y': '0.3060000038146973',
#    'xG': '0.052670326083898544',
#    'player': 'Serge Gnabry',
#    'h_a': 'a',
#    'player_id': '993',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17706',
#    'h_team': 'Bochum',
#    'a_team': 'Bayern Munich',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2022-02-12 14:30:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'}]}

# %%
script = scripts[1].string

start_index = script.index("('")+2
end_index = script.index("')")
json_string = script[start_index:end_index]
json_string = json_string.encode("utf8").decode("unicode_escape")
players_dict = json.loads(json_string)

# %%
players_dict['h']
# Out:
# 11

# %%
for i in scripts:
    if 'shotsData' in i:
        print(i)
