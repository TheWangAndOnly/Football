# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests 
from bs4 import BeautifulSoup
import json
from pprint import pprint
import matplotlib.image as mpimg
import matplotlib.patches as patches
from PIL import Image
from io import BytesIO
from highlight_text import htext
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
from mplsoccer.pitch import Pitch


pd.set_option("display.max_rows", None, "display.max_columns", None)
background = "#463F3A"
text_color = 'w'
primary = '#C8102E'
secondary = 'lightblue'
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

# %%
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match
# Out:
# Please enter the match id: 17706

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
scripts = soup.find_all('script')

# %%
print(scripts[1].string)
# Out:
# 	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22457001\x22,\x22minute\x22\x3A\x225\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.865\x22,\x22Y\x22\x3A\x220.25299999237060544\x22,\x22xG\x22\x3A\x220.051986921578645706\x22,\x22player\x22\x3A\x22J\x5Cu00fcrgen\x20Locadia\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x226542\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2217706\x22,\x22h_team\x22\x3A\x22Bochum\x22,\x22a_team\x22\x3A\x22Bayern\x20Munich\x22,\x22h_goals\x22\x3A\x224\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D02\x2D12\x2014\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Gerrit\x20Holtmann\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22457003\x22,\x22minute\x22\x3A\x2213\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.8540000152587891\x22,\x22Y\x22\x3A\x220.49400001525878906\x22,\x22xG\x22\x3A\x220.12363
# ...

# %%
script_ = scripts[2].string

start_index_ = script_.index("('")+2
end_index_ = script_.index("')")
json_string_ = script_[start_index:end_index]
json_string_ = json_string_.encode("utf8").decode("unicode_escape")
players_dict_ = json.loads(json_string)

# %%
script.index("('")
# Out:
# 31

# %%
script = scripts[1].string

start_index = script.index("('")+2
end_index = script.index("')")
json_string = script[start_index:end_index]
json_string = json_string.encode("utf8").decode("unicode_escape")
players_dict = json.loads(json_string)

# %%
for i in scripts:
    if 'shotsData' in i:
        print(i)

# %%
import os 
cpu = os.cpu_count()
cpu
# Out:
# 4
